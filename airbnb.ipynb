# %% [markdown]
# # kaggle airbnb feature study

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Draw inline
# %matplotlib inline

# Set figure aesthetics
sns.set_style("white", {'ytick.major.size': 10.0})
sns.set_context("poster", font_scale=1.1)

# %%
train_users = pd.read_csv("./input/sessions.csv")

# %%
train_users.head(11)
# Out:
#        user_id          action action_type            action_detail  \
# 0   d1mm9tcy42          lookup         NaN                      NaN
# 1   d1mm9tcy42  search_results       click      view_search_results
# 2   d1mm9tcy42          lookup         NaN                      NaN
# 3   d1mm9tcy42  search_results       click      view_search_results
# 4   d1mm9tcy42          lookup         NaN                      NaN
# 5   d1mm9tcy42  search_results       click      view_search_results
# 6   d1mm9tcy42          lookup         NaN                      NaN
# 7   d1mm9tcy42     personalize        data  wishlist_content_update
# 8   d1mm9tcy42           index        view      view_search_results
# 9   d1mm9tcy42          lookup         NaN                      NaN
# 10  d1mm9tcy42  search_results       click      view_search_results
#
#         device_type  secs_elapsed
# 0   Windows Desktop         319.0
# 1   Windows Desktop       67753.0
# 2   Windows Desktop         301.0
# ...

# %%
users_action = train_users['action']
users_action_type = train_users['action_type']
users_action_detail = train_users['action_detail']
users_device_type = train_users['device_type']
users_action.describe()
# Out:
# count     10488111
# unique         359
# top           show
# freq       2768278
# Name: action, dtype: object

# %%
train_users['action'].count()
# Out:
# 10488111

# %%
plt.figure(figsize=(30,10))
users_action_type.value_counts(dropna=False).plot(kind='bar', color='#FD5C64', rot=0)
plt.xticks(rotation=40, ha='center')
plt.xlabel('users_action_type')
sns.despine()

# %%
plt.figure(figsize=(15,8))
users_action_type.value_counts(dropna=False).plot(kind='bar', color='#FD5C64', rot=0)
plt.xticks(rotation=40, ha='center')
plt.xlabel('action')
sns.despine()

# %%
users_action_type.value_counts(dropna=True)
# Out:
# view                3560902
# data                2103770
# click               1996183
# -unknown-           1031170
# submit               623357
# message_post          87103
# partner_callback      19132
# booking_request       18773
# modify                 1139
# booking_response          4
# Name: action_type, dtype: int64

# %%
plt.figure(figsize=(15,8))
users_action_detail.value_counts(dropna=True)
# Out:
# view_search_results               1776885
# p3                                1376550
# -unknown-                         1031141
# wishlist_content_update            706824
# user_profile                       656839
# change_trip_characteristics        487744
# similar_listings                   364624
# user_social_connections            336799
# update_listing                     269779
# listing_reviews                    269021
# dashboard                          152952
# user_wishlists                     152672
# header_userpic                     141830
# message_thread                     132395
# edit_profile                       108686
# message_post                        87103
# contact_host                        81041
# unavailable_dates                   77795
# confirm_email_link                  58422
# create_user                         54878
# change_contact_host_dates           52517
# user_profile_content_update         50434
# ...

# %%
len(users_action_detail.value_counts(dropna=True))
# Out:
# 155

# %%
plt.figure(figsize=(30,8))
users_device_type.value_counts(dropna=False).plot(kind='bar', color='#FD5C64', rot=0)
plt.xticks(rotation=40, ha='center')
plt.xlabel('users_device_type')
sns.despine()
.save("dongkuang.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-63d0936f2ab5> in <module>()
#       4 plt.xlabel('users_device_type')
#       5 sns.despine()
# ----> 6 plt.save("dongkuang.png")
#       7
#       8
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'save'
